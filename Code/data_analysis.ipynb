# %%
import pandas as pd

# %%
df = pd.read_pickle('/Users/yannikhubrich/Documents/Studium/6Semester/FitechFinance/Data/df_esg')
df
# Out:
#       palmOil controversialWeapons gambling socialScore nuclear furLeather  \
# Value   False                False    False        8.06   False      False
# Value   False                False    False       13.56   False      False
# Value   False                False    False       11.61   False      False
# Value   False                False    False       13.54   False      False
# Value   False                False    False       16.92   False      False
# ...       ...                  ...      ...         ...     ...        ...
# Value   False                False    False        6.57    True      False
# Value   False                False    False        7.58   False      False
# Value   False                False    False       11.65   False      False
# Value   False                False    False       13.62   False      False
# Value   False                False    False         7.7   False      False
#
#       alcoholic    gmo catholic socialPercentile  ... percentile  \
# ...
